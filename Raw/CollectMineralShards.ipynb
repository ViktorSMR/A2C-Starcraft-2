# %%
from Net.actorCritic import A2C_v2
import Net.networks as net
from Env.env import *
from Obs.obs import *
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
RESOLUTION = 32
game_params = dict(feature_screen=RESOLUTION, feature_minimap=RESOLUTION, action_space="FEATURES") 
game_names = {1:'MoveToBeacon',
              2:'CollectMineralShards',
              3:'DefeatRoaches',
              4:'FindAndDefeatZerglings',
              5:'DefeatZerglingsAndBanelings',
              6:'CollectMineralsAndGas',
              7:'BuildMarines'
              }
map_name = game_names[2]
screen_names = ['visibility_map', 'player_relative', 'selected', 'unit_density', 'unit_density_aa']
minimap_names = []
obs_proc_params = {'screen_names':screen_names, 'minimap_names':minimap_names, 'select_all':False}
action_names = ['no_op', 'select_army', 'Move_screen']
action_dict = get_action_dict(action_names)
spatial_model = net.SpatialFeatures
nonspatial_model = net.NonSpatialFeatures

n_channels = 32
n_features = 256

n_steps = 40
max_n_steps = 25000
steps_count = 100
loss_freq = 50

# %%
op = ObsProcesser(**obs_proc_params)
in_channels = np.sum(op.get_n_channels())
spatial_dict = {'in_channels':in_channels}
nonspatial_dict = {'resolution':RESOLUTION}

# %%
en = init_game(game_params, map_name)

# %% [markdown]
# import torch
# agent = torch.load("Results\\CollectMineralShards0\\model.pth")
# mean_rw_history = torch.load("Results\\CollectMineralShards0\\mean_rw_history.pth")
# loss_history = torch.load("Results\\CollectMineralShards0\\loss_history.pth")
# step = 1200

# %%
agent = A2C(en, spatial_model, nonspatial_model, spatial_dict, nonspatial_dict, n_features, n_channels, action_dict=action_dict,
           gamma=0.99, beta=0.7, eta=-0.001)

# %%
en.close()

# %%
test_env = Env(game_params, map_name, obs_proc_params, action_dict)
env = Env(game_params, map_name, obs_proc_params, action_dict)

# %%
train(agent, test_env, env, map_name, n_steps, max_n_steps, steps_count, loss_freq)
# Out:
#  48%|██████████████████████████████████▌                                     | 12003/25000 [5:26:08<5:53:09,  1.63s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-92d2cf75283e> in <module>
# ----> 1 train(agent, test_env, env, map_name, n_steps, max_n_steps, steps_count, loss_freq)
#
# ~\папки\Untitled Folder\Env\env.py in train(agent, test_env, env, map_name, n_steps, max_n_steps, steps_count, loss_freq, step, mean_rw_history, loss_history)
#     123             states = np.append(states, state, axis=0)
#     124             action, log_prob, entropy = agent.step(state, action_mask)
# --> 125             new_state, reward, done, bootstrap, action_mask = env.step(action)
#     126             rewards = np.append(rewards, reward, axis=0)
#     127             log_probs = torch.cat((log_probs, log_prob), 0)
#
# ~\папки\Untitled Folder\Env\env.py in step(self, actions)
#      47         self.action_dict = action_dict
#      48     def step(self, actions):
# ---> 49         obs = self.env.step(actions)
#      50         new_state_dict = self.op.get_state(obs)
#      51         new_state = merge_screen_and_minimap(new_state_dict)
#
# E:\Anaconda\lib\site-packages\pysc2\lib\stopwatch.py in _stopwatch(*args, **kwargs)
#     210       def _stopwatch(*args, **kwargs):
#     211         with self(name):
# --> 212           return func(*args, **kwargs)
#     213       return _stopwatch
#     214     if callable(name_or_func):
#
# E:\Anaconda\lib\site-packages\pysc2\env\sc2_env.py in step(self, actions, step_mul)
#     546
#     547     self._state = environment.StepType.MID
# --> 548     return self._step(step_mul)
#     549
#     550   def _step(self, step_mul=None):
#
# E:\Anaconda\lib\site-packages\pysc2\env\sc2_env.py in _step(self, step_mul)
#     563                     current_game_loop=current_game_loop)
#     564
# --> 565     return self._observe(target_game_loop=target_game_loop)
#     566
#     567   def _apply_action_delays(self, actions):
#
# E:\Anaconda\lib\site-packages\pysc2\env\sc2_env.py in _observe(self, target_game_loop)
#     668
#     669   def _observe(self, target_game_loop):
# --> 670     self._get_observations(target_game_loop)
#     671
#     672     # TODO(tewalds): How should we handle more than 2 agents and the case where
#
# E:\Anaconda\lib\site-packages\pysc2\env\sc2_env.py in _get_observations(self, target_game_loop)
#     634
#     635     with self._metrics.measure_observation_time():
# --> 636       self._obs, self._agent_obs = zip(*self._parallel.run(
#     637           (parallel_observe, c, f)
#     638           for c, f in zip(self._controllers, self._features)))
#
# E:\Anaconda\lib\site-packages\pysc2\lib\run_parallel.py in run(self, funcs)
#      54     funcs = [f if callable(f) else functools.partial(*f) for f in funcs]
#      55     if len(funcs) == 1:  # Ignore threads if it's not needed.
# ---> 56       return [funcs[0]()]
#      57     if len(funcs) > self._workers:  # Lazy init and grow as needed.
#      58       self.shutdown()
#
# E:\Anaconda\lib\site-packages\pysc2\env\sc2_env.py in parallel_observe(c, f)
#     629     # Transform in the thread so it runs while waiting for other observations.
#     630     def parallel_observe(c, f):
# --> 631       obs = c.observe(target_game_loop=target_game_loop)
#     632       agent_obs = f.transform_obs(obs)
#     633       return obs, agent_obs
#
# E:\Anaconda\lib\site-packages\pysc2\lib\remote_controller.py in _valid_status(self, *args, **kwargs)
#      97             "`%s` called while in state: %s, valid: (%s)" % (
#      98                 func.__name__, self.status, ",".join(map(str, valid))))
# ---> 99       return func(self, *args, **kwargs)
#     100     return _valid_status
#     101   return decorator
#
# E:\Anaconda\lib\site-packages\pysc2\lib\stopwatch.py in _stopwatch(*args, **kwargs)
#     210       def _stopwatch(*args, **kwargs):
#     211         with self(name):
# --> 212           return func(*args, **kwargs)
#     213       return _stopwatch
#     214     if callable(name_or_func):
#
# E:\Anaconda\lib\site-packages\pysc2\lib\remote_controller.py in observe(self, disable_fog, target_game_loop)
#     246   def observe(self, disable_fog=False, target_game_loop=0):
#     247     """Get a current observation."""
# --> 248     obs = self._client.send(observation=sc_pb.RequestObservation(
#     249         game_loop=target_game_loop,
#     250         disable_fog=disable_fog))
#
# E:\Anaconda\lib\site-packages\pysc2\lib\protocol.py in send(self, **kwargs)
#     149     req.id = next(self._count)
#     150     try:
# --> 151       res = self.send_req(req)
#     152     except ConnectionError as e:
#     153       raise ConnectionError("Error during %s: %s" % (name, e))
#
# E:\Anaconda\lib\site-packages\pysc2\lib\protocol.py in send_req(self, request)
#     129     """Write a pre-filled Request and return the Response."""
#     130     self.write(request)
# --> 131     return self.read()
#     132
#     133   def send(self, **kwargs):
#
# E:\Anaconda\lib\site-packages\pysc2\lib\stopwatch.py in _stopwatch(*args, **kwargs)
#     210       def _stopwatch(*args, **kwargs):
#     211         with self(name):
# --> 212           return func(*args, **kwargs)
#     213       return _stopwatch
#     214     if callable(name_or_func):
#
# E:\Anaconda\lib\site-packages\pysc2\lib\protocol.py in read(self)
#     100                 self._port)
#     101       start = time.time()
# --> 102     response = self._read()
#     103     if FLAGS.sc2_verbose_protocol:
#     104       self._log("-------------- [%s] Read %s in %0.1f msec --------------\n%s",
#
# E:\Anaconda\lib\site-packages\pysc2\lib\protocol.py in _read(self)
#     181     with sw("read_response"):
#     182       with catch_websocket_connection_errors():
# --> 183         response_str = self._sock.recv()
#     184     if not response_str:
#     185       raise ProtocolError("Got an empty response from SC2.")
#
# E:\Anaconda\lib\site-packages\websocket\_core.py in recv(self)
#     360         """
#     361         with self.readlock:
# --> 362             opcode, data = self.recv_data()
#     363         if opcode == ABNF.OPCODE_TEXT:
#     364             return data.decode("utf-8")
#
# E:\Anaconda\lib\site-packages\websocket\_core.py in recv_data(self, control_frame)
#     383             tuple of operation code and string(byte array) value.
#     384         """
# --> 385         opcode, frame = self.recv_data_frame(control_frame)
#     386         return opcode, frame.data
#     387
#
# E:\Anaconda\lib\site-packages\websocket\_core.py in recv_data_frame(self, control_frame)
#     404         """
#     405         while True:
# --> 406             frame = self.recv_frame()
#     407             if (isEnabledForTrace()):
#     408                 trace("++Rcv raw: " + repr(frame.format()))
#
# E:\Anaconda\lib\site-packages\websocket\_core.py in recv_frame(self)
#     443         self.frame_buffer.recv_frame(): ABNF frame object
#     444         """
# --> 445         return self.frame_buffer.recv_frame()
#     446
#     447     def send_close(self, status=STATUS_NORMAL, reason=b""):
#
# E:\Anaconda\lib\site-packages\websocket\_abnf.py in recv_frame(self)
#     349
#     350             # Payload
# --> 351             payload = self.recv_strict(length)
#     352             if has_mask:
#     353                 payload = ABNF.mask(mask, payload)
#
# E:\Anaconda\lib\site-packages\websocket\_abnf.py in recv_strict(self, bufsize)
#     370             # buffers allocated and then shrunk, which results in
#     371             # fragmentation.
# --> 372             bytes_ = self.recv(min(16384, shortage))
#     373             self.recv_buffer.append(bytes_)
#     374             shortage -= len(bytes_)
#
# E:\Anaconda\lib\site-packages\websocket\_core.py in _recv(self, bufsize)
#     527     def _recv(self, bufsize):
#     528         try:
# --> 529             return recv(self.sock, bufsize)
#     530         except WebSocketConnectionClosedException:
#     531             if self.sock:
#
# E:\Anaconda\lib\site-packages\websocket\_socket.py in recv(sock, bufsize)
#     111             bytes_ = sock.recv(bufsize)
#     112         else:
# --> 113             bytes_ = _recv()
#     114     except socket.timeout as e:
#     115         message = extract_err_message(e)
#
# E:\Anaconda\lib\site-packages\websocket\_socket.py in _recv()
#      88     def _recv():
#      89         try:
# ---> 90             return sock.recv(bufsize)
#      91         except SSLWantReadError:
#      92             pass
#
# KeyboardInterrupt:

# %%
env.close()

# %%
evaluate(test_env, agent, 25)
# Out:
# 57.72

# %%
test_env.close()
